# %%
# This function imports the `fetch_movie_data` function from the
# movie_analysis module and uses it to retrieve movie data
# from the TMDb API using a list of movie IDs.

from movie_analysis import fetch_movie_data, api_key, clean_basic_movie_data




# The function sends requests to TMDb API and returns a DataFrame

df = fetch_movie_data(movie_ids, api_key)

# ----------------------------------------------
# Preview the First Few Rows of the DataFrame

# Clean and preprocess the data
#df_cleaned = clean_basic_movie_data(df)

df.head()
# Out:
#  Movie ID 0 not found. Status: 404
#    adult                     backdrop_path
# 0  False  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg  \
# 1  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg
# 2  False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg
# 3  False  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg
# 4  False  /sCzcYW9h55WcesOqA12cgEr9Exw.jpg
#
#                                belongs_to_collection     budget
# 0  {'id': 86311, 'name': 'The Avengers Collection...  356000000  \
# 1  {'id': 87096, 'name': 'Avatar Collection', 'po...  237000000
# 2  {'id': 10, 'name': 'Star Wars Collection', 'po...  245000000
# 3  {'id': 86311, 'name': 'The Avengers Collection...  300000000
# 4                                               None  200000000
#
#                                               genres
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...  \
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 3  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# ...

# %%
df_cleaned = clean_basic_movie_data(df)
df_cleaned.head(2)
# Out:
#                       backdrop_path  belongs_to_collection    budget  genres
# 0  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg                    NaN  0.000356     NaN  \
# 1  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg                    NaN  0.000237     NaN
#
#        id origin_country original_language
# 0  299534           [US]                en  \
# 1   19995           [US]                en
#
#                                             overview  popularity
# 0  After the devastating events of Avengers: Infi...     31.4799  \
# 1  In the 22nd century, a paraplegic Marine is di...     31.6851
#
#                         poster_path  ...  production_countries  release_date
# 0  /ulzhLuWrPK07P1YkdWQLZnQh1JL.jpg  ...                   NaN    2019-04-24  \
# 1  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg  ...                   NaN    2009-12-15
#
#     revenue  runtime  spoken_languages                      tagline
# 0  0.002799      181               NaN           Avenge the fallen.  \
# ...

# %%
# from movie_analysis import generate_visualizations

# %%
from movie_analysis import generate_visualizations


plot_charts = generate_visualizations(df_cleaned)
plot_charts

# %%
import importlib
import movie_analysis  # import first
importlib.reload(movie_analysis)  #  reload to force update

# ============================================
# Run the full data cleaning pipeline on the movie DataFrame
# Applies all cleaning steps: drop columns, extract fields,
# handle data types, fix anomalies, and filter rows
# ============================================

from movie_analysis import clean_basic_movie_data

df_cleaned = clean_basic_movie_data(df)

# Preview the cleaned DataFrame
df_cleaned.head(2)
# Out:
#                       backdrop_path  belongs_to_collection    budget  genres
# 0  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg                    NaN  0.000356     NaN  \
# 1  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg                    NaN  0.000237     NaN
#
#        id origin_country original_language
# 0  299534           [US]                en  \
# 1   19995           [US]                en
#
#                                             overview  popularity
# 0  After the devastating events of Avengers: Infi...     31.4799  \
# 1  In the 22nd century, a paraplegic Marine is di...     31.6851
#
#                         poster_path  ...  production_countries  release_date
# 0  /ulzhLuWrPK07P1YkdWQLZnQh1JL.jpg  ...                   NaN    2019-04-24  \
# 1  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg  ...                   NaN    2009-12-15
#
#     revenue  runtime  spoken_languages                      tagline
# 0  0.002799      181               NaN           Avenge the fallen.  \
# ...

# %%
import importlib
import movie_analysis  # import first
importlib.reload(movie_analysis)  #  reload to force update
from movie_analysis import extract_credits_fields

df = extract_credits_fields(df)
df.head(2)
# Out:
#  Movie ID 0 not found. Status: 404
#                       backdrop_path    belongs_to_collection  budget
# 0  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg  The Avengers Collection   356.0  \
# 1  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg        Avatar Collection   237.0
#
#                                      genres      id origin_country
# 0          Adventure|Science Fiction|Action  299534           [US]  \
# 1  Action|Adventure|Fantasy|Science Fiction   19995           [US]
#
#   original_language                                           overview
# 0                en  After the devastating events of Avengers: Infi...  \
# 1                en  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                       poster_path  ...
# 0     31.4799  /ulzhLuWrPK07P1YkdWQLZnQh1JL.jpg  ...  \
# 1     31.6851  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg  ...
#
#                       production_countries release_date      revenue  runtime
# ...

# %%
df["genres"]
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# Name: genres, dtype: float64

# %%
import importlib
import movie_analysis  # Make sure this is the correct filename (no .py extension)
importlib.reload(movie_analysis)  # Reload in case you edited the file

from movie_analysis import (
    rank_movies,
    
)
# Run ranking function to get all top/bottom stats
kpi_results = rank_movies(df)

# View highest rated movies (with ≥10 votes)
#kpi_results['highest_rated']

# View lowest profit movies
#kpi_results['lowest_profit']

# View highest ROI (budget ≥ 10M)
#kpi_results['highest_roi']

# Search 1: Bruce Willis in Sci-Fi + Action movies
search_movies(df, actor="Bruce Willis", genres=["Science Fiction", "Action"])

# Search 2: Uma Thurman, directed by Quentin Tarantino
search_movies(df, actor="Uma Thurman", director="Quentin Tarantino", sort_by="runtime")
# Out:
#  Movie ID 0 not found. Status: 404
#                       backdrop_path    belongs_to_collection  budget
# 0  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg  The Avengers Collection   356.0  \
# 1  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg        Avatar Collection   237.0
#
#                                      genres      id origin_country
# 0          Adventure|Science Fiction|Action  299534           [US]  \
# 1  Action|Adventure|Fantasy|Science Fiction   19995           [US]
#
#   original_language                                           overview
# 0                en  After the devastating events of Avengers: Infi...  \
# 1                en  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                       poster_path  ...
# 0     31.4799  /ulzhLuWrPK07P1YkdWQLZnQh1JL.jpg  ...  \
# 1     31.6851  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg  ...
#
#                       production_countries release_date      revenue  runtime
# ...

# %%
analyze_franchise_vs_standalone(df_f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Search 1: Bruce Willis in Sci-Fi + Action movies
# ----> 2 search_movies(df_final, actor="Bruce Willis", genres=["Science Fiction", "Action"])
#       4 # Search 2: Uma Thurman, directed by Quentin Tarantino
#       5 search_movies(df_final, actor="Uma Thurman", director="Quentin Tarantino", sort_by="runtime")
#
# NameError: name 'search_movies' is not defined

# %%
import importlib
import movie_analysis  # Make sure this is the correct filename (no .py extension)
importlib.reload(movie_analysis)  # Reload in case you edited the file

from movie_analysis import generate_visualizations

generate_visualizations(df_cleaned)
# Out:
#  Movie ID 0 not found. Status: 404
#                       backdrop_path    belongs_to_collection  budget
# 0  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg  The Avengers Collection   356.0  \
# 1  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg        Avatar Collection   237.0
#
#                                      genres      id origin_country
# 0          Adventure|Science Fiction|Action  299534           [US]  \
# 1  Action|Adventure|Fantasy|Science Fiction   19995           [US]
#
#   original_language                                           overview
# 0                en  After the devastating events of Avengers: Infi...  \
# 1                en  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                       poster_path  ...
# 0     31.4799  /ulzhLuWrPK07P1YkdWQLZnQh1JL.jpg  ...  \
# 1     31.6851  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg  ...
#
#                       production_countries release_date      revenue  runtime
# ...
